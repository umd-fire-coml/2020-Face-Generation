# %%
import tensorflow_datasets as tfds
import tensorflow as tf

from dcgan import DCGAN

# When running with GPU, this is required to make it work
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Using TensorFlow backend.

# %%
ds = tfds.load('celeb_a', data_dir="./", download=False)
# Out:
# WARNING:tensorflow:Entity <bound method TopLevelFeature.decode_example of FeaturesDict({
#     'attributes': FeaturesDict({
#         '5_o_Clock_Shadow': Tensor(shape=(), dtype=tf.bool),
#         'Arched_Eyebrows': Tensor(shape=(), dtype=tf.bool),
#         'Attractive': Tensor(shape=(), dtype=tf.bool),
#         'Bags_Under_Eyes': Tensor(shape=(), dtype=tf.bool),
#         'Bald': Tensor(shape=(), dtype=tf.bool),
#         'Bangs': Tensor(shape=(), dtype=tf.bool),
#         'Big_Lips': Tensor(shape=(), dtype=tf.bool),
#         'Big_Nose': Tensor(shape=(), dtype=tf.bool),
#         'Black_Hair': Tensor(shape=(), dtype=tf.bool),
#         'Blond_Hair': Tensor(shape=(), dtype=tf.bool),
#         'Blurry': Tensor(shape=(), dtype=tf.bool),
#         'Brown_Hair': Tensor(shape=(), dtype=tf.bool),
#         'Bushy_Eyebrows': Tensor(shape=(), dtype=tf.bool),
#         'Chubby': Tensor(shape=(), dtype=tf.bool),
#         'Double_Chin': Tensor(shape=(), dtype=tf.bool),
# ...

# %%
dcgan = DCGAN(ds["train"], img_rows=128, img_cols=128)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 65536)             2752512
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 8, 8, 1024)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 1024)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 1024)      26215424
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 1024)      4096
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 16, 1024)      0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 1024)      0
# ...

# %%
dcgan.train(epochs=100, batch_num=100, batch_size=16, save_interval=1)
# Out:
# ----- Epoch 0 -----
# C:\Users\hasso\Anaconda3\envs\fire-face-gen\lib\site-packages\keras\engine\training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Batch 0/3 - Discrim loss: 0.254589, accuracy: 62.50%
#              - Gener loss: 0.552502
# C:\Users\hasso\Anaconda3\envs\fire-face-gen\lib\site-packages\keras\engine\training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Batch 1/3 - Discrim loss: 0.218583, accuracy: 50.00%
#              - Gener loss: 0.253393
# Batch 2/3 - Discrim loss: 0.202555, accuracy: 50.00%
#              - Gener loss: 0.119058
# ...
